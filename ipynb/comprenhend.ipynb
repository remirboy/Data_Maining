# %%
import json
import boto3

comprehend = boto3.client('comprehend',aws_access_key_id='ASIA6DBTT7YCGOGD7IWZ',aws_secret_access_key='jLu/ixDyNny8n4mtMvcs+l9R+rIAvQGtQQ/VlsuE',region_name='us-east-1')

# %%
text = "Dear remir.ziatdinov@gmail.com, This is a friendly notification that you have exceeded 50% of your available credits. Please save your work before your credits are exhausted.Email : remir.ziatdinov@gmail.comAccount Type : Advanced Databases and Data MiningExpires	: 05-31-2021 PDTCredits Remaining	: $49.89 out of $100 Regards, Vocareum SupportTo request assistance with your AWS Educate account, please click the I don't have an AWS Account button on the following page - https://aws.amazon.com/education/awseducate/contact-us/"

# %%
print('Calling DetectEntities')
print(json.dumps(comprehend.detect_entities(Text=text, LanguageCode='en'), sort_keys=True, indent=4))
print('End of DetectEntities\n')
# Out:
# Calling DetectEntities
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# <ipython-input-7-828a7f87a83f> in <module>
#       1 print('Calling DetectEntities')
# ----> 2 print(json.dumps(comprehend.detect_entities(Text=text, LanguageCode='en'), sort_keys=True, indent=4))
#       3 print('End of DetectEntities\n')
#
# /usr/local/lib/python3.7/site-packages/botocore/client.py in _api_call(self, *args, **kwargs)
#     355                     "%s() only accepts keyword arguments." % py_operation_name)
#     356             # The "self" in this scope is referring to the BaseClient.
# --> 357             return self._make_api_call(operation_name, kwargs)
#     358
#     359         _api_call.__name__ = str(py_operation_name)
#
# /usr/local/lib/python3.7/site-packages/botocore/client.py in _make_api_call(self, operation_name, api_params)
# ...

# %%
print('Calling DetectKeyPhrases')
print(json.dumps(comprehend.detect_key_phrases(Text=text, LanguageCode='en'), sort_keys=True, indent=4))
print('End of DetectKeyPhrases\n')

# %%
print('Calling DetectSyntax')
print(json.dumps(comprehend.detect_syntax(Text=text, LanguageCode='en'), sort_keys=True, indent=4))
print('End of DetectSyntax\n')

# %%
print('Calling DetectSentiment')
print(json.dumps(comprehend.detect_sentiment(Text=text, LanguageCode='en'), sort_keys=True, indent=4))
print('End of DetectSentiment\n')
